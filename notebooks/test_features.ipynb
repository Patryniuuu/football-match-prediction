# %%
import pandas as pd
import db.io

# %%
liverpool_raw_df = db.io.load_raw_team_stats_from_db("Liverpool", "2024-2025")
all_raw_df = db.io.load_all_teams_raw_stats_from_db("2024-2025")

# %%
#sprawdzmy ile jest nulli w kazdej kolumnie
nulls_count = liverpool_raw_df.isna().sum()
nulls_only = nulls_count[nulls_count>0]
nulls_only
# Out:
# xGA        8
# SoT%       1
# G/Sh       1
# G/SoT      1
# Dist       8
# npxG       8
# npxG/Sh    8
# G-xG       8
# np:G-xG    8
# xA         8
# PPA        8
# PrgP       8
# Def 3rd    8
# Mid 3rd    8
# Att 3rd    8
# Att Pen    8
# Live       8
# 1/3        8
# CPA        8
# Dis        8
# xG         8
# Poss       1
# PrgDist    8
# dtype: int64

# %%
#sprawdzimy w jakich meczach nie ma danych
null_rows = liverpool_raw_df[liverpool_raw_df.isna().any(axis=1)]
null_rows_per_comp = null_rows.groupby("Comp").apply(lambda x: x.isnull().sum())
null_rows_per_comp_filterd = null_rows_per_comp.loc[:, (null_rows_per_comp != 0).any()]
null_rows_per_comp_filterd
# Out:
# C:\Users\48666\AppData\Local\Temp\ipykernel_7648\592067856.py:3: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   null_rows_per_comp = null_rows.groupby("Comp").apply(lambda x: x.isnull().sum())
#          xGA  SoT%  G/Sh  G/SoT  Dist  npxG  npxG/Sh  G-xG  np:G-xG  xA  ...  \
# Comp                                                                     ...
# EFL Cup    6     0     0      0     6     6        6     6        6   6  ...
# FA Cup     2     1     1      1     2     2        2     2        2   2  ...
#
#          Mid 3rd  Att 3rd  Att Pen  Live  1/3  CPA  Dis  xG  Poss  PrgDist
# Comp
# EFL Cup        6        6        6     6    6    6    6   6     0        6
# ...

# %%
# Out:
#           Date   Time            Comp                Round    Venue Result  \
# 0   2024-08-17  12:30  Premier League          Matchweek 1     Away      W
# 1   2024-08-25  16:30  Premier League          Matchweek 2     Home      W
# 2   2024-09-01  16:00  Premier League          Matchweek 3     Away      W
# 3   2024-09-14  15:00  Premier League          Matchweek 4     Home      L
# 4   2024-09-17  21:00    Champions Lg         League phase     Away      W
# 5   2024-09-21  15:00  Premier League          Matchweek 5     Home      W
# 6   2024-09-25  20:00         EFL Cup          Third round     Home      W
# 7   2024-09-28  17:30  Premier League          Matchweek 6     Away      W
# 8   2024-10-02  20:00    Champions Lg         League phase     Home      W
# 9   2024-10-05  12:30  Premier League          Matchweek 7     Away      W
# 10  2024-10-20  16:30  Premier League          Matchweek 8     Home      W
# ...
